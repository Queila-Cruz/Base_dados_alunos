# %% [markdown]
# <a href="https://colab.research.google.com/github/Queila-Cruz/Base_dados_alunos/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone COLAR A URL
# !git clone https://github.com/Queila-Cruz/Base_dados_alunos.git
# Out:
# Cloning into 'Base_dados_alunos'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
#Vamos contar quantos alunos temos

# 1 saber onde est o arquivo
# 2 pedir que o python leia o arquivo
# 3 contar e mostrar as informações
baseDados = "/content/Base_dados_alunos/github - Página1.csv"

# usar uma função de abertura de arquivos
# with open ( arquivo, método) as apelido
# métodos - leitura - "r" read
# métodos - colocar informações - "a" append
# métodos - deletar tudo e colocar de novo - "w" write
# sempre que temos dois pontos, estamos dizendo ao computador o que ele vai fazer na linha anterior
with open(baseDados, "r" ) as arquivo:
  qtd_linhas = arquivo.readlines()

  print(len(qtd_linhas))
# Out:
# 53
